# %%
import pandas as pd
import xgboost as xgb
import sklearn
#from sklearn.metrics import root_mean_squared_error
#from sklearn.model_selection import train_test_split

# %%
df_train = pd.read_csv('datasets/train_data.csv')
df_test = pd.read_csv('datasets/test_data.csv')

# %%
X_train = df_train.iloc[:, :-1].values  # All columns except the last as features
y_train = df_train.iloc[:, -1].values   # Last column as target
X_predict = df_test.iloc[:, 1:].values   # All columns except the first as features

# %%
# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
df_models = pd.read_csv('XGBoost_models_test.csv')
df_models
# Out:
#        Model  max_depth  learning_rate  n_estimators  alpha  gamma  subsample  \
# 0    Model 1          6          0.050          1000    NaN    NaN        NaN
# 1    Model 2         10          0.010          2000    NaN    NaN        NaN
# 2    Model 3          6          0.010          1000    NaN    NaN        NaN
# 3    Model 4          6          0.010          2000    NaN    NaN        NaN
# 4    Model 5         10          0.001          2000    NaN    NaN        NaN
# 5    Model 6         10          0.100          2000    NaN    NaN        NaN
# 6    Model 7          7          0.030          1500    NaN    NaN        NaN
# 7    Model 8         10          0.010          2000    NaN  0.100        NaN
# 8    Model 9         10          0.010          2000    0.5    NaN        NaN
# 9   Model 10         10          0.010          2000    NaN    NaN        0.8
# 10  Model 11         10          0.010          2000    NaN    NaN        NaN
# ...

# %%
# Initialize the XGBoost model
#model = xgb.XGBRegressor(objective='reg:squarederror', max_depth=10, learning_rate=0.01, n_estimators=5000, alpha=0.1, gamma=0.005, subsample=0.7, colsample_bytree=0.5) # RMSE: 0.3989387210301139
model = xgb.XGBRegressor(objective='reg:squarederror', max_depth=10, learning_rate=0.01, n_estimators=2000, alpha=0.1, gamma=0.01, subsample=0.8, colsample_bytree=0.8) # RMSE: 0.4053927478804889
#model = xgb.XGBRegressor(objective='reg:squarederror', max_depth=10, learning_rate=0.01, n_estimators=2000, alpha=0.1, gamma=0.01, subsample=0.7, colsample_bytree=0.5) # RMSE: 0.40399452974564165

# %%
# Train the model
model.fit(X_train, y_train)
# Out:
# XGBRegressor(alpha=0.1, base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.01, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=2000, n_jobs=None,
#              num_parallel_tree=None, ...)

# %%
# Make predictions on the test set to get RMSE
#y_pred = model.predict(X_test)

# %%
# Evaluate performance
rmse = root_mean_squared_error(y_test, y_pred)
print(f'RMSE: {rmse}')
# Out:
# RMSE: 0.42235815260003806

# %% [markdown]
# # Predictions for the challenge

# %%
# Make predictions on the test set
y_pred = model.predict(X_predict)

# %%
predictions_df = pd.DataFrame(y_pred)

# %%
column_from_df1 = df_test["Unnamed: 0"]
column_from_df2 = predictions_df.iloc[:, -1]

# %%
predictions_df = pd.concat([column_from_df1, column_from_df2], axis=1)

# %%
predictions_df.columns = ['id', 'target_feature']

# %%
predictions_df
# Out:
#            id  target_feature
# 0        2016        8.480897
# 1        2017        8.663519
# 2        2018        8.713242
# 3        2019        7.984666
# 4        2020        7.387378
# ...       ...             ...
# 64507  193531        5.631757
# 64508  193532        5.215324
# 64509  193533        5.181744
# 64510  193534        5.438616
# 64511  193535        5.434981
#
# [64512 rows x 2 columns]

# %%
# Save submission as CSV file
predictions_df.to_csv('D:\\Python\\Predict the wind speed at a wind turbine\\submissions\\oleg_bissing_submission_11.csv', index=False)
